# %% [markdown]
# # Matlplotlib and Seaborn Practice

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,2])
plt.show()

# %%
plt.plot([1,2])
plt.plot([2,2])
plt.plot([3,2])
plt.show()

# %%
plt.plot([1,2])
plt.plot([2,3])
plt.plot([3,1])
plt.show()

# %%
x = [1,2,3,4,5]
y = [10,20,30,40,50]

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [10,20,30,10,30]

plt.plot(x,y)
plt.show()

# %%
lst = [10,20,30,10,30]

plt.plot(lst, color = "red",marker="o", mfc="w",mec="k",ms=10,label="AGE",lw=2,ls=":")
plt.title("Line Plot", color = "k", fontsize=17)
plt.xlabel("ID", fontsize=13, color = "g")
plt.ylabel("Age", fontsize=13,  color = "g")
plt.legend()
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]

y1 = [50, 20, 60, 40, 10]
y2 = [20, 200, 40, 20, 50]
y3 = [10, 30, 40, 100, 60]
y4 = [30, 40, 10, 50, 80]

plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)

plt.show()

# %%
x = [1, 2, 3, 4, 5]

y1 = [50, 20, 60, 40, 10]
y2 = [20, 200, 40, 20, 50]
y3 = [10, 30, 40, 100, 60]
y4 = [30, 40, 10, 50, 80]

plt.figure(figsize=(10,4))

plt.plot(x,y1, color="b", label = "Royal Enfield", marker="o",lw=1)
plt.plot(x,y2, color="r", label = "Himalyan", marker="o",lw=1)
plt.plot(x,y3, color="k", label = "Harley", marker="o",lw=1)
plt.plot(x,y4, color="g", label = "BMW GS-1200", marker="o",lw=1)

plt.title("Bike Detail using LINE PLOT")
plt.xlabel("Number of Days")
plt.ylabel("Distance Covered in KM")
plt.xticks(np.arange(1,6, step=1))
plt.yticks(np.arange(0,201, step=20))


plt.legend()
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [50, 20, 60, 40, 10]
y2 = [20, 200, 40, 20, 50]
y3 = [10, 30, 40, 100, 60]
y4 = [30, 40, 10, 50, 80]

plt.figure(figsize=(12, 7))
plt.plot(x, y1, color='b', linestyle='--', linewidth=2, label="Royal Enfield", marker="o")
plt.plot(x, y2, color='m', linestyle='-.', linewidth=2, label="Himalyan", marker="o")
plt.plot(x, y3, color='y', linestyle=':', linewidth=2, label="BMW GS-1200", marker="o")
plt.plot(x, y4, color='r', linestyle='-', linewidth=2, label="Harley", marker="o")

# Adding annotations
for i in range(len(x)):
    plt.text(x[i], y1[i], f'{y1[i]}', ha='center', va='bottom')
    plt.text(x[i], y2[i], f'{y2[i]}', ha='center', va='bottom')
    plt.text(x[i], y3[i], f'{y3[i]}', ha='center', va='bottom')
    plt.text(x[i], y4[i], f'{y4[i]}', ha='center', va='bottom')

# Shaded region
plt.fill_between(x, y1, y2, color='gray', alpha=0.4, label="Range between Y1 and Y2")

plt.title('Bike Detail using Line Plot', color="k", fontsize=25)
plt.xlabel('Days', fontsize=25)
plt.ylabel('Km', fontsize=25)
plt.xticks(np.arange(1, 6, step=1))
plt.yticks(np.arange(10, 201, step=20))
plt.legend()
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]

y1 = [50, 20, 60, 40, 10]
y2 = [20, 200, 40, 20, 50]
y3 = [10, 30, 40, 100, 60]
y4 = [30, 40, 10, 50, 80]

plt.figure(figsize=(10,4))

plt.bar(x,y1, color="b", label = "Royal Enfield",width=0.2)
plt.bar(x,y2, color="r", label = "Himalyan", width=0.2)
plt.bar(x,y3, color="k", label = "Harley", width=0.2)
plt.bar(x,y4, color="g", label = "BMW GS-1200", width=0.2)

plt.title("Bike Detail using LINE PLOT")
plt.xlabel("Number of Days")
plt.ylabel("Distance Covered in KM")
plt.xticks(np.arange(1,6, step=1))
plt.yticks(np.arange(0,201, step=20))


plt.legend()

plt.show()

# %%
x1= [1, 2, 3, 4, 5]
x2 = [i + 0.2 for i in x1]
x3 = [i + 0.4 for i in x1]
x4 = [i + 0.6 for i in x1]

y1 = [50, 20, 60, 40, 10]
y2 = [20, 200, 40, 20, 50]
y3 = [10, 30, 40, 100, 60]
y4 = [30, 40, 10, 50, 80]

plt.figure(figsize=(10,4))

plt.bar(x1,y1, color="b", label = "Royal Enfield",width=0.2, ec="g")
plt.bar(x2,y2, color="r", label = "Himalyan", width=0.2,ec="g")
plt.bar(x3,y3, color="k", label = "Harley", width=0.2,ec="g")
plt.bar(x4,y4, color="g", label = "BMW GS-1200", width=0.2,ec="g")

plt.title("Bike Detail using LINE PLOT")
plt.xlabel("Number of Days")
plt.ylabel("Distance Covered in KM")


plt.xticks(np.arange(1,6, step=1))

plt.yticks(np.arange(10, 201, step=20))


plt.legend()
plt.grid(axis='y')

plt.show()

# %%
x = [1, 2, 3, 4, 5]

y1 = [50, 20, 60, 40, 10]
y2 = [20, 200, 40, 20, 50]
y3 = [10, 30, 40, 100, 60]
y4 = [30, 40, 10, 50, 80]

plt.figure(figsize=(12,6))

plt.scatter(x,y1, color="b", label = "Royal Enfield", marker="o",s=100 )
plt.scatter(x,y2, color="r", label = "Himalyan", marker="o",s=100)
plt.scatter(x,y3, color="k", label = "Harley", marker="o",s=100)
plt.scatter(x,y4, color="g", label = "BMW GS-1200", marker="o",s=100)

plt.title("Bike Detail using LINE PLOT")
plt.xlabel("Number of Days")
plt.ylabel("Distance Covered in KM")
plt.xticks(np.arange(1,6, step=1))
plt.yticks(np.arange(0,201, step=20))


plt.legend()
# plt.grid()
plt.show()

# %%
slices = [1,2,3,4]

plt.pie(slices)
plt.show()

# %%
slices = [5,8,7,12]
cols = ['g','r','b','m']
label = ['Laptop', 'Headphone','Android','Macboook']

plt.pie(slices, labels=label, colors=cols, autopct='%1.1f', shadow=True,startangle=60, explode=(0,0,0,0.2))
plt.title('Pie Plot')
plt.show()

# %%
fig = plt.figure(figsize=(12,6))
fig.add_subplot(projection='3d')
x = [1, 2, 3, 4, 5]

y1 = [50, 20, 60, 40, 10]
y2 = [20, 200, 40, 20, 50]
y3 = [10, 30, 40, 100, 60]
y4 = [30, 40, 10, 50, 80]


plt.scatter(x,y1, color="b", label = "Royal Enfield", marker="o",s=100 )
plt.scatter(x,y2, color="r", label = "Himalyan", marker="o",s=100)
plt.scatter(x,y3, color="k", label = "Harley", marker="o",s=100)
plt.scatter(x,y4, color="g", label = "BMW GS-1200", marker="o",s=100)

plt.title("Bike Detail using LINE PLOT")
plt.xlabel("Number of Days")
plt.ylabel("Distance Covered in KM")
plt.xticks(np.arange(1,6, step=1))
plt.yticks(np.arange(0,201, step=20))


plt.legend()
# plt.grid()
plt.show()

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('taxis')
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df['fare']
# Out:
# 0        7.0
# 1        5.0
# 2        7.5
# 3       27.0
# 4        9.0
#         ...
# 6428     4.5
# 6429    58.0
# 6430    16.0
# 6431     6.0
# 6432    15.0
# Name: fare, Length: 6433, dtype: float64

# %%
sns.histplot(df['fare'], bins=20, color='g')
plt.show()

# %%
sns.kdeplot(df)
plt.show()

# %%
sns.kdeplot(df['distance'], color='g')
plt.show()

# %%
sns.distplot(df['distance'], color='g', bins=30)
plt.show()
# Out:
# C:\Users\patid\AppData\Local\Temp\ipykernel_88376\1492121999.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['distance'], color='g', bins=30)

# %%
sns.distplot(df['total'], color='g', bins=30)
plt.show()
# Out:
# C:\Users\patid\AppData\Local\Temp\ipykernel_88376\886876469.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total'], color='g', bins=30)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df['fare'])
# Out:
# <Axes: ylabel='fare'>

# %%
df.corr(numeric_only=True)
# Out:
#                passengers  distance      fare           tip         tolls  \
# passengers       1.000000  0.009411  0.007637  2.109930e-02 -2.903055e-03
# distance         0.009411  1.000000  0.920108  4.525887e-01  6.352674e-01
# fare             0.007637  0.920108  1.000000  4.886124e-01  6.093069e-01
# tip              0.021099  0.452589  0.488612  1.000000e+00  4.136188e-01
# tolls           -0.002903  0.635267  0.609307  4.136188e-01  1.000000e+00
# total            0.015708  0.904676  0.974358  6.461858e-01  6.831422e-01
# pickup_hour     -0.004406 -0.025343 -0.011395  3.254855e-02  9.886207e-03
# pickup_day       0.007213 -0.002056 -0.003597  1.748249e-02  1.380210e-02
# pickup_month     0.005586  0.006921  0.008734  1.007962e-02  2.865959e-03
# dropoff_hour    -0.005473 -0.011875  0.004658  3.809811e-02  2.290454e-02
# dropoff_day      0.005685 -0.002991 -0.004410  1.809040e-02  1.401311e-02
# dropoff_month    0.029297  0.026143  0.024424 -2.902177e-14 -4.505508e-15
#
# ...

# %%
plt.figure(figsize=(15, 10))

sns.heatmap(df.corr(numeric_only=True),cmap='coolwarm', annot=True, vmin=-1, vmax=1)
plt.show()

# %%
df2 = sns.load_dataset("titanic")
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(df2['age'], bins=30, color='m')
plt.show()

# %%
sns.kdeplot(df2['age'], color='m')
plt.show()

# %%
sns.distplot(df2['age'], bins=30, color='m')
plt.show()
# Out:
# C:\Users\patid\AppData\Local\Temp\ipykernel_88376\2616018133.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['age'], bins=30, color='m')

# %%
sns.boxplot(df2['age'], color='m')
plt.show()

# %%
sns.histplot(df2, bins=30, color='m')
plt.show()

# %%
sns.boxplot(df2,  color='m')
plt.show()

# %%
df2.corr(numeric_only=True)
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='plasma', vmin=1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(15, 10))

sns.heatmap(df.corr(numeric_only=True),cmap='Blues', annot=True, vmin=-1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='cividis', vmin=1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='inferno', vmin=1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Greens', vmin=1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='viridis', vmin=1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='magma', vmin=1, vmax=1)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Purples', vmin=1, vmax=1)
plt.show()
